# %% [markdown]
# # 🌟 Assignment 2. Operation "AI GeoGuessr"
#
# ### Deadline: Monday, October 21, 2024, 11:59:00 PM CET (GMT +2)
#
# ## 🎯 Mission Overview
#
# The operation consists of two independent missions. Similar to the previous operation, students are required to solve the tasks by achieving the required score and answering the follow-up questions.
#
# ## 🧪 Neural Networks and Unsupervised Learning
#
# 1. **Mission 2.1 (Supervised Learning)**:
#    - Solve a supervised learning problem using a Neural Network (MLP). This is similar to a problem you have worked on before but requires the use of a neural network model.
#
# 2. **Mission 2.2 (Unsupervised Learning)**:
#    - Given an unlabeled dataset, your task is to cluster similar data points and achieve 100% clustering accuracy. You will not have access to the true labels, but you can verify your cluster assignments using the Kaggle competition provided.
#
# ## 📝 Delivery Format (Blackboard)
#
# Please submit **two files**:
# 1. The completed Jupyter notebook.
# 2. The solution for the second dataset as a CSV file with two `int` columns: `['ID', 'cluster']`.
#
# ## Kaggle details
# - Invitation link: https://www.kaggle.com/t/6610d6c6ba314eac9ead0b7a47695700
# - Kaggle is a popular platform for data science competitions.
# - It allows us to create a Private competition where you can submit your solutions and verify whether you are thinking in the right direction.
# - The results of the competition is visible only to the competition participants.
# - We will not grade the submissions on Kaggle, we set it up to let you check your clustering.
# - You still have to deliver the `.csv` file of the solution and the complete `.ipynb` notebook with discussions and solution code.
#
#
#
# > Good luck, comrade!
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import sklearn

# %% [markdown]
# # 🧠 Mission 2.1: Decoding SkyNet's Neural Encryption **(using Neural Networks)**
#
# ### 🌐 The Discovery
# The dataset consists of the same "Synapse Cipher" data from Assignment 1.
#
# ### 🎯 Your Mission
# 1. Implement a neural network (MLP) using one of the following frameworks: Keras, PyTorch, or TensorFlow.
# 2. Solve the non-linear problem without manual feature engineering. So the manual feature engineering is not allowed!
# 3. Predict SkyNet's binary decisions (0 or 1) based on paired signals.
# 4. Enhance performance by using techniques such as learning rate scheduling, selecting a good optimizer, and fine-tuning training hyperparameters.
#
# > Note: There are no restrictions on the tricks you can use — just achieve the required accuracy. Stack more layers, use AdamW, scheduling, ect. Have fun :)
#
# ### 📊 Formal Requirements
# 1. **Implementation**:
#    - Develop a Neural Network using predefined functions/layers.
#    - Use one of the popular frameworks: Keras, PyTorch, or TensorFlow.
#    - Implement a manual learning rate scheduler with warmup and cosine decay.
#
# 2. **Performance**: Achieve at least **0.92** accuracy on the test set.
#
# 3. **Discussion**:
#    - How did you achieve the reproducibility of the results?
#
#    Used set_random_seed and op determinism. See cell below.
#
#    - Visualize the network's architecture and decision boundary.
#
#    Done. See below. My PC couldnt import the plot_model method...
#
#    - Which optimizer did you choose? Discuss the differences between the SGD and Adam optimizers.
#
#    I chose the SGD optimizer because it was the one I learned and understood at the time. When I tried with the Adam optimizer it didnt change much. This may be because of a small or predictive dataset.  We can see on the decition boundary on the adam looks more sinsitive.
#
#    - Visualize the learning rate dynamics. Did the learning rate scheduling improve performance? Why or why not?
# The learning rate did not improve the preforamnce. This may be because the data was not complex enough or just too small to notice any difference.
#
#    - Conduct an ablation study of each architectural and optimization choice concerning test accuracy.
#
#    We can see that the SGD's boundary looks more correct at first. But we can see that there are some anomalies in the data, which Adam was more sensitive to.

# %%
# For network architecture visualization, other options are totally fine
from tensorflow.keras import utils
from tensorflow.keras.utils import plot_model, set_random_seed
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import LearningRateScheduler

from tensorflow.config.experimental import enable_op_determinism

# %%
data = pd.read_csv('nn_data.csv')
train = data[data['split'] == 'train']
test = data[data['split'] == 'test']

train = train.drop(columns='split')
test = test.drop(columns='split')


X_train = train.drop(columns=['y'])
y_train = train['y']

X_test = test.drop(columns=['y'])
y_test = test['y']

set_random_seed(1)
enable_op_determinism()

# %%
modelSGD = tf.keras.models.Sequential()
modelSGD.add(Dense(8, input_dim=X_train.shape[1], activation='relu'))
modelSGD.add(Dense(2, activation='relu'))
modelSGD.add(Dense(1, activation='sigmoid'))

initial_lr = 0.1
modelSGD.compile(optimizer=keras.optimizers.SGD(), 
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy()],
              )

modelSGDNoCallback = tf.keras.models.Sequential()
modelSGDNoCallback.add(Dense(8, input_dim=X_train.shape[1], activation='relu'))
modelSGDNoCallback.add(Dense(2, activation='relu'))
modelSGDNoCallback.add(Dense(1, activation='sigmoid'))

initial_lr = 0.1
modelSGDNoCallback.compile(optimizer=keras.optimizers.SGD(), 
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy()],
              )



modelAdamNoCallback = tf.keras.models.Sequential()
modelAdamNoCallback.add(Dense(8, input_dim=X_train.shape[1], activation='relu'))
modelAdamNoCallback.add(Dense(2, activation='relu'))
modelAdamNoCallback.add(Dense(1, activation='sigmoid'))

modelAdamNoCallback.compile(optimizer="Adam", 
              loss=keras.losses.BinaryCrossentropy(), 
              metrics=[keras.metrics.BinaryAccuracy()])


modelAdam = tf.keras.models.Sequential()
modelAdam.add(Dense(8, input_dim=X_train.shape[1], activation='relu'))
modelAdam.add(Dense(2, activation='relu'))
modelAdam.add(Dense(1, activation='sigmoid'))

modelAdam.compile(optimizer="Adam", 
              loss=keras.losses.BinaryCrossentropy(), 
              metrics=[keras.metrics.BinaryAccuracy()])
# Out:
# /Users/polinaermakova/Documents/GitHub/Introduction-to-machine-learning/Assignment2/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-07 16:00:46.943965: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-10-07 16:00:46.944006: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-10-07 16:00:46.944013: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-10-07 16:00:46.944331: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-07 16:00:46.944341: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
def lr_scheduler(epoch, lr, epochs):
    warmup_epochs = 5
    if epoch < warmup_epochs:
        return initial_lr * (epoch + 1) / warmup_epochs
    else:
        cosine_decay = 0.5 * (1 + np.cos(np.pi * (epoch - warmup_epochs) / (epochs - warmup_epochs)))
        return initial_lr * cosine_decay

epochs = 100

lr_schedule_callback = LearningRateScheduler(lambda epoch, lr: lr_scheduler(epoch, lr, epochs))

# %%
epochs = 100
historySGD = modelSGD.fit(X_train, y_train, 
                    epochs=epochs, 
                    #batch_size=32, 
                    #validation_split=0.2, 
                    verbose=1,
                    callbacks=[lr_schedule_callback],
                    )

historySGDNoCallback = modelSGDNoCallback.fit(X_train, y_train, 
                    epochs=epochs, 
                    #batch_size=32, 
                    #validation_split=0.2, 
                    verbose=1,
                    )



y_predSGD = (modelSGD.predict(X_test) >= 0.5).astype("int32")

y_predSGDNoCallback = (modelSGD.predict(X_test) >= 0.5).astype("int32")


from sklearn.metrics import accuracy_score

accuracySGD = accuracy_score(y_test, y_predSGD)
accuracySGDNoCallback = accuracy_score(y_test, y_predSGDNoCallback)


print(f"Test Accuracy SGD: {accuracySGD}")
print(f"Test Accuracy SGD no callback: {accuracySGDNoCallback}")


modelSGD.summary()


modelSGDNoCallback.summary()


historyAdam = modelAdam.fit(X_train, y_train, 
                    epochs=epochs, 
                    #batch_size=32, 
                    #validation_split=0.2, 
                    verbose=1,
                    callbacks=[lr_schedule_callback],
                    )

historyAdamNoCallback = modelAdamNoCallback.fit(X_train, y_train, 
                    epochs=epochs, 
                    #batch_size=32, 
                    #validation_split=0.2, 
                    verbose=1,
                    )



y_predAdam = (modelAdam.predict(X_test) >= 0.5).astype("int32")

y_predAdamNoCallback = (modelAdamNoCallback.predict(X_test) >= 0.5).astype("int32")

from sklearn.metrics import accuracy_score

accuracyAdam = accuracy_score(y_test, y_predAdam)
accuracyAdamNoCallback = accuracy_score(y_test, y_predAdamNoCallback)
print(f"Test Accuracy Adam: {accuracyAdam}")
print(f"Test Accuracy Adam No Callback: {accuracyAdamNoCallback}")

modelAdam.summary()
# Out:
# Epoch 1/100
# 2025-10-07 16:00:47.647475: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.4800 - loss: 0.7042 - learning_rate: 0.0200
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5040 - loss: 0.7018 - learning_rate: 0.0400
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5340 - loss: 0.6986 - learning_rate: 0.0600
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5480 - loss: 0.6955 - learning_rate: 0.0800
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.4780 - loss: 0.6931 - learning_rate: 0.1000
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.4800 - loss: 0.6918 - learning_rate: 0.1000
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5200 - loss: 0.6912 - learning_rate: 0.1000
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5560 - loss: 0.6911 - learning_rate: 0.0999
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5640 - loss: 0.6911 - learning_rate: 0.0998
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5720 - loss: 0.6911 - learning_rate: 0.0996
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5720 - loss: 0.6911 - learning_rate: 0.0993
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5720 - loss: 0.6912 - learning_rate: 0.0990
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5740 - loss: 0.6912 - learning_rate: 0.0987
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5780 - loss: 0.6913 - learning_rate: 0.0983
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5760 - loss: 0.6913 - learning_rate: 0.0978
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5700 - loss: 0.6914 - learning_rate: 0.0973
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - binary_accuracy: 0.5640 - loss: 0.6915 - learning_rate: 0.0967
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5660 - loss: 0.6916 - learning_rate: 0.0961
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5660 - loss: 0.6917 - learning_rate: 0.0955
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5620 - loss: 0.6918 - learning_rate: 0.0947
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5640 - loss: 0.6918 - learning_rate: 0.0940
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5660 - loss: 0.6919 - learning_rate: 0.0932
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5620 - loss: 0.6920 - learning_rate: 0.0923
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5620 - loss: 0.6922 - learning_rate: 0.0914
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5620 - loss: 0.6923 - learning_rate: 0.0905
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5620 - loss: 0.6924 - learning_rate: 0.0895
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5560 - loss: 0.6925 - learning_rate: 0.0884
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5580 - loss: 0.6926 - learning_rate: 0.0873
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5580 - loss: 0.6927 - learning_rate: 0.0862
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5600 - loss: 0.6928 - learning_rate: 0.0851
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5600 - loss: 0.6929 - learning_rate: 0.0839
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5620 - loss: 0.6930 - learning_rate: 0.0826
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5620 - loss: 0.6932 - learning_rate: 0.0814
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5560 - loss: 0.6933 - learning_rate: 0.0801
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5580 - loss: 0.6934 - learning_rate: 0.0787
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5560 - loss: 0.6935 - learning_rate: 0.0773
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5540 - loss: 0.6936 - learning_rate: 0.0759
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5480 - loss: 0.6937 - learning_rate: 0.0745
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5540 - loss: 0.6939 - learning_rate: 0.0731
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5520 - loss: 0.6940 - learning_rate: 0.0716
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5540 - loss: 0.6941 - learning_rate: 0.0701
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5540 - loss: 0.6942 - learning_rate: 0.0686
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5520 - loss: 0.6943 - learning_rate: 0.0670
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5560 - loss: 0.6944 - learning_rate: 0.0655
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5580 - loss: 0.6946 - learning_rate: 0.0639
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5600 - loss: 0.6947 - learning_rate: 0.0623
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5580 - loss: 0.6948 - learning_rate: 0.0607
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5620 - loss: 0.6949 - learning_rate: 0.0590
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5620 - loss: 0.6950 - learning_rate: 0.0574
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5600 - loss: 0.6951 - learning_rate: 0.0558
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5640 - loss: 0.6952 - learning_rate: 0.0541
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5620 - loss: 0.6953 - learning_rate: 0.0525
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5620 - loss: 0.6953 - learning_rate: 0.0508
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5600 - loss: 0.6954 - learning_rate: 0.0492
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5600 - loss: 0.6955 - learning_rate: 0.0475
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5600 - loss: 0.6955 - learning_rate: 0.0459
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5580 - loss: 0.6955 - learning_rate: 0.0442
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5580 - loss: 0.6955 - learning_rate: 0.0426
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5580 - loss: 0.6955 - learning_rate: 0.0410
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5600 - loss: 0.6955 - learning_rate: 0.0393
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5580 - loss: 0.6955 - learning_rate: 0.0377
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5560 - loss: 0.6954 - learning_rate: 0.0361
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5560 - loss: 0.6953 - learning_rate: 0.0345
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5560 - loss: 0.6953 - learning_rate: 0.0330
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5560 - loss: 0.6952 - learning_rate: 0.0314
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5560 - loss: 0.6950 - learning_rate: 0.0299
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5520 - loss: 0.6949 - learning_rate: 0.0284
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5480 - loss: 0.6948 - learning_rate: 0.0269
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5500 - loss: 0.6946 - learning_rate: 0.0255
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5460 - loss: 0.6945 - learning_rate: 0.0241
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5400 - loss: 0.6943 - learning_rate: 0.0227
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5420 - loss: 0.6941 - learning_rate: 0.0213
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5420 - loss: 0.6939 - learning_rate: 0.0199
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5460 - loss: 0.6937 - learning_rate: 0.0186
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5500 - loss: 0.6936 - learning_rate: 0.0174
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5420 - loss: 0.6934 - learning_rate: 0.0161
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5400 - loss: 0.6932 - learning_rate: 0.0149
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5520 - loss: 0.6930 - learning_rate: 0.0138
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5420 - loss: 0.6928 - learning_rate: 0.0127
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5440 - loss: 0.6926 - learning_rate: 0.0116
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5380 - loss: 0.6924 - learning_rate: 0.0105
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5380 - loss: 0.6922 - learning_rate: 0.0095
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5360 - loss: 0.6919 - learning_rate: 0.0086
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5320 - loss: 0.6917 - learning_rate: 0.0077
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5360 - loss: 0.6915 - learning_rate: 0.0068
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5420 - loss: 0.6913 - learning_rate: 0.0060
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5440 - loss: 0.6911 - learning_rate: 0.0053
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5420 - loss: 0.6909 - learning_rate: 0.0045
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5420 - loss: 0.6908 - learning_rate: 0.0039
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5460 - loss: 0.6906 - learning_rate: 0.0033
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5440 - loss: 0.6904 - learning_rate: 0.0027
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5440 - loss: 0.6902 - learning_rate: 0.0022
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5420 - loss: 0.6901 - learning_rate: 0.0017
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5420 - loss: 0.6900 - learning_rate: 0.0013
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5460 - loss: 0.6899 - learning_rate: 9.8100e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5380 - loss: 0.6898 - learning_rate: 6.8193e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5380 - loss: 0.6897 - learning_rate: 4.3680e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5360 - loss: 0.6896 - learning_rate: 2.4585e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5360 - loss: 0.6896 - learning_rate: 1.0932e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5360 - loss: 0.6895 - learning_rate: 2.7337e-05
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5140 - loss: 0.6916
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5080 - loss: 0.6917
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5060 - loss: 0.6923
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5040 - loss: 0.6930
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5020 - loss: 0.6937
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5020 - loss: 0.6946
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5000 - loss: 0.6955
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5020 - loss: 0.6965
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5100 - loss: 0.6975
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5120 - loss: 0.6985
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.6996
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5220 - loss: 0.7008
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5220 - loss: 0.7020
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7032
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5240 - loss: 0.7045
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5220 - loss: 0.7058
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5220 - loss: 0.7071
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5180 - loss: 0.7085
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5140 - loss: 0.7098
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5120 - loss: 0.7112
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5140 - loss: 0.7125
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5160 - loss: 0.7138
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5180 - loss: 0.7150
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7162
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7172
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5200 - loss: 0.7182
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5220 - loss: 0.7191
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5220 - loss: 0.7200
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5220 - loss: 0.7207
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5220 - loss: 0.7214
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7221
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7227
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7232
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5200 - loss: 0.7236
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5180 - loss: 0.7240
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5180 - loss: 0.7243
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5160 - loss: 0.7246
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.5140 - loss: 0.7248
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5160 - loss: 0.7249
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5120 - loss: 0.7250
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5120 - loss: 0.7250
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5120 - loss: 0.7250
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5100 - loss: 0.7249
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5100 - loss: 0.7248
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5100 - loss: 0.7246
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5100 - loss: 0.7244
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5080 - loss: 0.7241
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5080 - loss: 0.7238
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5080 - loss: 0.7235
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5080 - loss: 0.7231
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5080 - loss: 0.7227
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5020 - loss: 0.7223
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.5020 - loss: 0.7218
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4980 - loss: 0.7213
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4940 - loss: 0.7208
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4940 - loss: 0.7203
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4920 - loss: 0.7197
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4900 - loss: 0.7191
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.4900 - loss: 0.7185
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4880 - loss: 0.7178
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.4880 - loss: 0.7172
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4880 - loss: 0.7165
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4880 - loss: 0.7158
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4860 - loss: 0.7152
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4860 - loss: 0.7145
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4860 - loss: 0.7137
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4860 - loss: 0.7130
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4860 - loss: 0.7123
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4860 - loss: 0.7116
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.4840 - loss: 0.7109
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4840 - loss: 0.7102
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4820 - loss: 0.7095
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4800 - loss: 0.7088
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4800 - loss: 0.7081
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4780 - loss: 0.7074
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4780 - loss: 0.7067
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.4780 - loss: 0.7060
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4780 - loss: 0.7053
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4760 - loss: 0.7047
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4760 - loss: 0.7040
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4760 - loss: 0.7034
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.4760 - loss: 0.7028
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4760 - loss: 0.7022
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4740 - loss: 0.7017
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4720 - loss: 0.7011
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4700 - loss: 0.7006
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4680 - loss: 0.7000
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4640 - loss: 0.6995
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4640 - loss: 0.6990
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4620 - loss: 0.6985
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.4600 - loss: 0.6981
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4600 - loss: 0.6976
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.4560 - loss: 0.6972
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4540 - loss: 0.6968
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4480 - loss: 0.6964
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4440 - loss: 0.6960
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4420 - loss: 0.6957
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4420 - loss: 0.6953
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4420 - loss: 0.6950
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.4420 - loss: 0.6947
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy SGD: 0.534
# Test Accuracy SGD no callback: 0.534
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47 (192.00 B)
#  Trainable params: 45 (180.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 8)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 2)              │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47 (192.00 B)
#  Trainable params: 45 (180.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - binary_accuracy: 0.5360 - loss: 0.6965 - learning_rate: 0.0200
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5800 - loss: 0.7098 - learning_rate: 0.0400
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.6060 - loss: 0.7617 - learning_rate: 0.0600
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.6060 - loss: 0.8035 - learning_rate: 0.0800
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5280 - loss: 1.3819 - learning_rate: 0.1000
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5700 - loss: 0.9001 - learning_rate: 0.1000
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5220 - loss: 2.3724 - learning_rate: 0.1000
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5000 - loss: 1.7970 - learning_rate: 0.0999
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5700 - loss: 0.8737 - learning_rate: 0.0998
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.5400 - loss: 0.7941 - learning_rate: 0.0996
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4600 - loss: 0.9334 - learning_rate: 0.0993
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5380 - loss: 0.9121 - learning_rate: 0.0990
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.4780 - loss: 1.4722 - learning_rate: 0.0987
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5460 - loss: 0.8724 - learning_rate: 0.0983
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5060 - loss: 1.8952 - learning_rate: 0.0978
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5600 - loss: 0.9109 - learning_rate: 0.0973
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - binary_accuracy: 0.4880 - loss: 1.9464 - learning_rate: 0.0967
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.5800 - loss: 0.9100 - learning_rate: 0.0961
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4680 - loss: 1.8248 - learning_rate: 0.0955
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - binary_accuracy: 0.4720 - loss: 0.9060 - learning_rate: 0.0947
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.4860 - loss: 1.4604 - learning_rate: 0.0940
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4960 - loss: 0.9018 - learning_rate: 0.0932
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4980 - loss: 1.4972 - learning_rate: 0.0923
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - binary_accuracy: 0.4880 - loss: 0.9093 - learning_rate: 0.0914
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4840 - loss: 1.4640 - learning_rate: 0.0905
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5060 - loss: 0.9111 - learning_rate: 0.0895
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4840 - loss: 1.4355 - learning_rate: 0.0884
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.9227 - learning_rate: 0.0873
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4720 - loss: 1.3844 - learning_rate: 0.0862
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5080 - loss: 0.9126 - learning_rate: 0.0851
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4660 - loss: 1.3429 - learning_rate: 0.0839
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4960 - loss: 0.9170 - learning_rate: 0.0826
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4600 - loss: 1.3063 - learning_rate: 0.0814
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5060 - loss: 0.8841 - learning_rate: 0.0801
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4700 - loss: 1.3074 - learning_rate: 0.0787
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.9026 - learning_rate: 0.0773
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4680 - loss: 1.2690 - learning_rate: 0.0759
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.9027 - learning_rate: 0.0745
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4720 - loss: 1.2412 - learning_rate: 0.0731
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5080 - loss: 0.8834 - learning_rate: 0.0716
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4700 - loss: 1.2323 - learning_rate: 0.0701
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5100 - loss: 0.8969 - learning_rate: 0.0686
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4820 - loss: 1.2006 - learning_rate: 0.0670
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5080 - loss: 0.8773 - learning_rate: 0.0655
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4800 - loss: 1.1894 - learning_rate: 0.0639
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4920 - loss: 0.8873 - learning_rate: 0.0623
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4940 - loss: 1.1586 - learning_rate: 0.0607
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4840 - loss: 0.8801 - learning_rate: 0.0590
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4980 - loss: 1.1390 - learning_rate: 0.0574
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4760 - loss: 0.8799 - learning_rate: 0.0558
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5020 - loss: 1.1236 - learning_rate: 0.0541
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4880 - loss: 0.8733 - learning_rate: 0.0525
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4980 - loss: 1.1108 - learning_rate: 0.0508
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4960 - loss: 0.8672 - learning_rate: 0.0492
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.4980 - loss: 1.1006 - learning_rate: 0.0475
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5120 - loss: 0.8545 - learning_rate: 0.0459
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.4920 - loss: 1.0941 - learning_rate: 0.0442
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.5240 - loss: 0.8427 - learning_rate: 0.0426
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4900 - loss: 1.0894 - learning_rate: 0.0410
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5380 - loss: 0.8327 - learning_rate: 0.0393
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4880 - loss: 1.0907 - learning_rate: 0.0377
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5460 - loss: 0.8279 - learning_rate: 0.0361
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.4960 - loss: 1.0933 - learning_rate: 0.0345
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5480 - loss: 0.8283 - learning_rate: 0.0330
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4900 - loss: 1.0991 - learning_rate: 0.0314
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5360 - loss: 0.8377 - learning_rate: 0.0299
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4900 - loss: 1.1057 - learning_rate: 0.0284
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5060 - loss: 0.8565 - learning_rate: 0.0269
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4940 - loss: 1.0986 - learning_rate: 0.0255
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4660 - loss: 0.8763 - learning_rate: 0.0241
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - binary_accuracy: 0.5020 - loss: 1.0684 - learning_rate: 0.0227
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.4460 - loss: 0.8965 - learning_rate: 0.0213
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.4560 - loss: 1.0167 - learning_rate: 0.0199
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - binary_accuracy: 0.4480 - loss: 0.8905 - learning_rate: 0.0186
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4520 - loss: 0.9361 - learning_rate: 0.0174
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4480 - loss: 0.8719 - learning_rate: 0.0161
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4620 - loss: 0.8490 - learning_rate: 0.0149
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4720 - loss: 0.8273 - learning_rate: 0.0138
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4780 - loss: 0.8015 - learning_rate: 0.0127
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4860 - loss: 0.7826 - learning_rate: 0.0116
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.4640 - loss: 0.7662 - learning_rate: 0.0105
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.4940 - loss: 0.7530 - learning_rate: 0.0095
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5160 - loss: 0.7440 - learning_rate: 0.0086
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.5180 - loss: 0.7396 - learning_rate: 0.0077
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5340 - loss: 0.7408 - learning_rate: 0.0068
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5380 - loss: 0.7506 - learning_rate: 0.0060
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - binary_accuracy: 0.4980 - loss: 0.7679 - learning_rate: 0.0053
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5200 - loss: 0.7313 - learning_rate: 0.0045
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5240 - loss: 0.7046 - learning_rate: 0.0039
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5120 - loss: 0.7049 - learning_rate: 0.0033
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5560 - loss: 0.6993 - learning_rate: 0.0027
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5480 - loss: 0.6993 - learning_rate: 0.0022
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5900 - loss: 0.7027 - learning_rate: 0.0017
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5740 - loss: 0.7115 - learning_rate: 0.0013
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5560 - loss: 0.7224 - learning_rate: 9.8100e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5540 - loss: 0.7068 - learning_rate: 6.8193e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.4960 - loss: 0.6938 - learning_rate: 4.3680e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5380 - loss: 0.6913 - learning_rate: 2.4585e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5080 - loss: 0.6902 - learning_rate: 1.0932e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5220 - loss: 0.6896 - learning_rate: 2.7337e-05
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.5060 - loss: 0.6926
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4920 - loss: 0.6918
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.4800 - loss: 0.6914
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4660 - loss: 0.6910
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4500 - loss: 0.6907
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4380 - loss: 0.6905
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4340 - loss: 0.6903
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4320 - loss: 0.6901
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4260 - loss: 0.6900
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4300 - loss: 0.6899
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4360 - loss: 0.6899
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4380 - loss: 0.6898
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4360 - loss: 0.6898
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4380 - loss: 0.6899
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4380 - loss: 0.6899
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4420 - loss: 0.6900
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.4420 - loss: 0.6900
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4460 - loss: 0.6900
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4460 - loss: 0.6901
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4480 - loss: 0.6901
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4500 - loss: 0.6902
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4480 - loss: 0.6902
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4500 - loss: 0.6903
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4540 - loss: 0.6904
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4680 - loss: 0.6904
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4680 - loss: 0.6905
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4680 - loss: 0.6905
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4720 - loss: 0.6905
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4740 - loss: 0.6905
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.4740 - loss: 0.6905
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4740 - loss: 0.6906
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4740 - loss: 0.6906
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4760 - loss: 0.6906
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4720 - loss: 0.6906
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4740 - loss: 0.6905
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4740 - loss: 0.6905
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4720 - loss: 0.6905
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.4700 - loss: 0.6904
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4740 - loss: 0.6904
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4740 - loss: 0.6904
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4760 - loss: 0.6904
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.4820 - loss: 0.6903
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - binary_accuracy: 0.4840 - loss: 0.6903
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - binary_accuracy: 0.4840 - loss: 0.6903
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.4840 - loss: 0.6903
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - binary_accuracy: 0.4900 - loss: 0.6903
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.4960 - loss: 0.6903
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4940 - loss: 0.6903
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - binary_accuracy: 0.4960 - loss: 0.6903
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5000 - loss: 0.6903
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5040 - loss: 0.6904
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5020 - loss: 0.6904
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5040 - loss: 0.6904
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5040 - loss: 0.6904
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5040 - loss: 0.6904
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - binary_accuracy: 0.5040 - loss: 0.6905
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5020 - loss: 0.6905
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4980 - loss: 0.6905
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.4960 - loss: 0.6906
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4960 - loss: 0.6906
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4920 - loss: 0.6906
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4980 - loss: 0.6907
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.4960 - loss: 0.6907
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5020 - loss: 0.6908
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5060 - loss: 0.6908
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5060 - loss: 0.6909
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5080 - loss: 0.6909
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5100 - loss: 0.6910
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.6910
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.6911
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6912
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.5140 - loss: 0.6912
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6913
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.6914
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5140 - loss: 0.6915
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6916
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6917
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6918
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.6919
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.6920
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5140 - loss: 0.6921
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6921
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.5140 - loss: 0.6922
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5180 - loss: 0.6923
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5180 - loss: 0.6923
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5180 - loss: 0.6924
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5160 - loss: 0.6925
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5160 - loss: 0.6926
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5160 - loss: 0.6927
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5160 - loss: 0.6928
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6928
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6929
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6930
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.5120 - loss: 0.6931
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5120 - loss: 0.6932
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.5140 - loss: 0.6933
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5120 - loss: 0.6934
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5100 - loss: 0.6935
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5080 - loss: 0.6936
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.5080 - loss: 0.6937
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test Accuracy Adam: 0.504
# Test Accuracy Adam No Callback: 0.454
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 8)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (552.00 B)
#  Trainable params: 45 (180.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 92 (372.00 B)

# %%
np.random.seed(567)
tf.random.set_seed(567)

epochs = 100

lrs_SGD = [lr_scheduler(i, initial_lr, epochs=100) for i in range(epochs)]
lrs_Adam = [lr_scheduler(i, initial_lr, epochs=100) for i in range(epochs)]

# Generate mesh grid for decision boundary
x0 = np.linspace(-4, 4, 200)
x1 = np.linspace(-4, 4, 200)
X0, X1 = np.meshgrid(x0, x1)
X = np.vstack([X0.ravel(), X1.ravel()]).T

# Creating subplots (2x2)
fig, axes = plt.subplots(3, 2, figsize=(8, 8))

# Plotting learning rate schedule for SGD
axes[0, 0].plot(lrs_SGD)
axes[0, 0].set_title('Learning Rate Schedule - SGD')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Learning Rate')

# Plotting learning rate schedule for Adam
axes[0, 1].plot(lrs_Adam)
axes[0, 1].set_title('Learning Rate Schedule - Adam')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Learning Rate')

# Assuming train is your dataset with columns x0, x1, and y

# Plot decision boundary for SGD (with scheduler)
y_SGD = modelSGD.predict(X).reshape(200, 200)
axes[1, 0].contourf(X0, X1, y_SGD, cmap='coolwarm', alpha=0.8, levels=1)
axes[1, 0].scatter(train['x0'], train['x1'], c=train['y'], cmap='coolwarm', alpha=0.5)
axes[1, 0].grid(True)
axes[1, 0].set_xlabel('x0')
axes[1, 0].set_ylabel('x1')
axes[1, 0].set_title('SGD with Scheduler')

# Plot decision boundary for Adam (= modelAdam.predict(X).reshape(200, 200)
axes[1, 1].contourf(X0, X1, y_Adam, cmap='coolwarm', alpha=0.8, levels=1)
axes[1, 1].scatter(train['x0'], train['x1'], c=train['y'], cmap='coolwarm', alpha=0.5)
axes[1, 1].grid(True)
axes[1, 1].set_xlabel('x0')
axes[1, 1].set_ylabel('x1')
axes[1, 1].set_title('Adam with Scheduler')

y_SGD = modelSGDNoCallback.predict(X).reshape(200, 200)
axes[2, 0].contourf(X0, X1, y_SGD, cmap='coolwarm', alpha=0.8, levels=1)
axes[2, 0].scatter(train['x0'], train['x1'], c=train['y'], cmap='coolwarm', alpha=0.5)
axes[2, 0].grid(True)
axes[2, 0].set_xlabel('x0')
axes[2, 0].set_ylabel('x1')
axes[2, 0].set_title('SGD without Scheduler')

# Plot decision boundary for Adam (with scheduler)
y_Adam = modelAdamNoCallback.predict(X).reshape(200, 200)
axes[2, 1].contourf(X0, X1, y_Adam, cmap='coolwarm', alpha=0.8, levels=1)
axes[2, 1].scatter(train['x0'], train['x1'], c=train['y'], cmap='coolwarm', alpha=0.5)
axes[2, 1].grid(True)
axes[2, 1].set_xlabel('x0')
axes[2, 1].set_ylabel('x1')
axes[2, 1].set_title('Adam without Scheduler')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
plt.figure(figsize=(6, 4))
plt.scatter(train['x0'], train['x1'], c=train['y'], cmap='coolwarm')
plt.grid(True)
plt.xlabel('x0', fontsize=14)
plt.ylabel('x1', fontsize=14)
plt.title('x1 vs. x0 Train', fontsize=16)
plt.colorbar()

# %% [markdown]
# # 📶📡🛰️🤳 Mission 2.2: Locate the AI Servers
#
# ### 🌐 The Discovery
# The NTNU Intelligence team has intercepted encrypted documentation that potentially reveals the locations of AI-compromised servers within Trondheim. Our analysts believe the data contains information about these servers' locations.
#
# However, the number of servers and their exact positions remain unknown. To execute a strategic response, we need to understand the intercepted data and pinpoint the main AI servers.
#
# We have also discovered a vulnerability in the AI's security: it has deployed a clustering verification feature on Kaggle. We can exploit this backdoor to validate our clustering hypotheses.
#
# ### 🎯 Your Mission
# Identify the number of hidden servers (clusters) in the dataset. Assign cluster labels to each row in the original dataset and validate your clustering solution on Kaggle.  When achieved the perfect clustering accuracy, find the precise locations of these servers (clusters).
#
# ### 🧠 The Challenge
# 1. **Large Dataset**: The intercepted data file contains numerous features, making direct manipulation and clustering difficult. Applying dimensionality reduction techniques could help reveal patterns.
# 2. **Unsupervised Learning**: No target labels are provided, so you must identify patterns based solely on the dataset's features.
# 3. **Data Obfuscation**: The AI has obfuscated the data, making it difficult to discern its true structure. You must effectively manipulate the data to visually identify server locations.
#
#
# ### 🚀 Your Tools
# - The intercepted AI dataset.
# - Skills in feature engineering, data manipulation, and visualization.
# - Clustering algorithms (e.g., KMeans, DBSCAN, Birch, Agglomerative Clustering, etc.) — [Clustering in Scikit-Learn](https://scikit-learn.org/stable/modules/clustering.html)
# - Dimensionality reduction techniques (e.g., PCA, t-SNE, Isomap, UMAP, etc.)
# - Kaggle competition platform with a daily submission limit of 50 attempts (~30 days * 50 submissions = 1500 total attempts per student).
#
# > Note: Kaggle competition link — [Kaggle Competition](https://www.kaggle.com/t/6610d6c6ba314eac9ead0b7a47695700)
#
# ### 📊 Formal Requirements
# 1. **Achieve 100% Clustering Accuracy** on Kaggle.
# > Note: The only way to check whether your clustering is correct is to submit it to Kaggle. We do not give you the clusters directly.
#
# 2. **Discussion Questions**:
#    - **Dimensionality Reduction**: Which dimensionality reduction methods helped you determine the correct number of clusters? Why did some methods work better than others? Explain the differences between PCA, t-SNE, and UMAP.
#
#    I used t-SNE to reduce the dataset to 3 dimensions. This method was effective because t-SNE is known for preserving the local structure of the data, which makes it ideal for visualizing complex, non-linear structures in the data. When clusters are elongated or irregularly shaped, t-SNE can provide a clearer separation between groups compared to methods like PCA. UMAP might work better in some cases depending on the data structure, but since my clusters were long and irregular, t-SNE provided a better separation
#
#    - **Clustering Approach**: Which clustering algorithm and hyperparameters did you use? Discuss the differences between algorithms like KMeans and DBSCAN.
#
# I used DBSCAN (Density-Based Spatial Clustering of Applications with Noise). This choice makes sense since DBSCAN is effective at finding arbitrarily shaped clusters, especially when clusters aren’t around a central point (centroid) like in KMeans. KMeans assumes that clusters are spherical and of equal size. It works well for datasets where clusters are clearly defined around centroids, but struggles with complex shapes or noise.
# DBSCAN, on the other hand, identifies clusters based on density and does not assume any specific shape. It’s robust to noise and can handle clusters of varying shapes and sizes. However, it may be sensitive to the choice of eps and min_samples.
#
#    - **Server Locations**: Identify the server locations. List the specific facilities in Trondheim and explain how you deduced their locations.
#
# By reshaping the data into 128x128 grids and using imshow(), I effectively visualized geographical data as images, which helped me identify server locations in Trondheim based on maps printed out. The locations were: Samfundet, Ikea, T spectrum and the Pier-bath.
#
#    - **Data Type Analysis**: What is the hidden data type in the dataset? How does this information influence feature extraction for clustering? Can it explain why some dimensionality reduction algorithms are more effective?
#
# Certain algorithms like t-SNE and UMAP are better at capturing non-linear structures, which can arise from complex data types like images or text. If the clusters are not linearly separable (which is common with hidden data types), PCA may struggle, while t-SNE or UMAP could capture the subtle variations better.
#
#    - **Advanced Task (Optional)**: Extract features using modern pre-trained neural networks for this data type. Apply dimensionality reduction and clustering algorithms to the extracted features.

# %%
data = pd.read_csv('unsupervised_data.csv', skiprows=1, header=None)
# Get the ID column

data.reset_index(drop=False, inplace=True)
data.rename(columns={'index': 'ID'}, inplace=True)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, DBSCAN
from sklearn.model_selection import train_test_split

#data

#data.columns = data.iloc[0]
#data = data.drop(0)
#data.columns = [str(col).replace("col_", "") for col in data.columns]
#data = data.loc[:, sorted(data.columns, key=lambda x: int(x) if x.isdigit() else x)]
#data = data.reset_index(drop=False, inplace=True)
#data.rename(columns={'index': 'ID'}, inplace=True)
#data = data.reset_index(drop=True)


data

# We can observe that the number of colimns are 128^2 = 16 384
# We can also sort the columns to fit the correct col_xx to the column number


tsne = TSNE(n_components=3, perplexity=22,random_state=40)
data_tsne = tsne.fit_transform(data.iloc[:,2:])

# The data seems to have some clusters. Let's apply DbScan to find the clusters
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=5, min_samples=10)
y_pred = dbscan.fit(data_tsne)
labels = dbscan.labels_



# Plot the data
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(data_tsne[:, 0], data_tsne[:, 1], data_tsne[:,2], c = labels)
plt.title('DBSCAN clusters on t-SNE')
plt.legend()
plt.show()


pred_df = pd.DataFrame(data=np.array([labels]).T, columns=["cluster"])

pred_df.to_csv("submission.csv")

# Må legge inn ID manuelt
# Out:
# /var/folders/rp/y8ykrgmd0k1356y_b74y2qpc0000gn/T/ipykernel_76885/135344731.py:40: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#scaler = StandardScaler()
#data_scaled = scaler.fit_transform(data)

# %%
# The dataset is heavy. Applying clustering directly on the dataset is not feasible, I guess.

# %%
# plt.hist(data.iloc[:, 2], bins=50, color='blue', alpha=0.5, label='Feature #2')
# plt.hist(data.iloc[:, 13021], bins=50, color='red', alpha=0.5, label='Feature #13021')
# plt.legend()

# %%
# To check your clustering, you need to assign the predicted cluster ids and submit it as a CSV file. The submission should be a CSV file with two columns: ID and cluster. 
# The ID column should contain the ID of the data point, and the cluster column should contain the cluster ID that the data point belongs to. 
# The cluster ID should be an integer. Current cluster IDs in sample_submission.csv are randomly generated.
submission = pd.read_csv('submission.csv')
submission
# Out:
#       Unnamed: 0  cluster
# 0              0        0
# 1              1        1
# 2              2        0
# 3              3        1
# 4              4        2
# ...          ...      ...
# 3995        3995        3
# 3996        3996        3
# 3997        3997        0
# 3998        3998        1
# 3999        3999        1
#
# [4000 rows x 2 columns]

# %%
# To find out where the servers are
with open("unsupervised_data.csv") as f:
    l = f.readline().split(',')
    
np_line = np.array([int(col[4:]) for col in l])
line = np_line.reshape(128,128)


s = np.argsort(np_line)
reshape = data.drop(columns='ID').to_numpy()
reshape = reshape[:, s].reshape(-1, 128, 128)

pictures = {5: "Trondheim Spektrum", 
            24: "Samfundet",
            41: "Pirbadet",
            42: "Ikea Leangen"
            }

fig, ax = plt.subplots(2,2, figsize=(8,8))
ax = ax.ravel()

i = 0
for id, label in pictures.items():
    ax[i].imshow(reshape[id], cmap="RdBu", label=label)
    ax[i].grid(False)
    ax[i].set_title(label)
    ax[i].set_xticks([])
    ax[i].set_yticks([])
    #ax[i].legend()
    i += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 🎯 Note: Clustering Accuracy Evaluation
#
#
# The clustering accuracy metric evaluates how well the predicted clusters match the true clusters, irrespective of the specific labels or names assigned to the clusters.
#
# This means that the evaluation focuses solely on the correct grouping of data points rather than the numerical labels of the clusters themselves.
#
# ## Key Characteristics
#
# - **Name-Independent**: The metric cares only about how well the data points are grouped together, not the specific numerical or categorical labels used for the clusters.
# - **Focus on Grouping**: The evaluation rewards cluster assignments that correctly group the same data points together, regardless of the specific labels assigned.
#
# ### Example
#
# If the true cluster assignments are:
#
# ```
# [0, 0, 0, 1, 1, 1]
# ```
#
# and your predicted cluster assignments are:
#
# ```
# [1, 1, 1, 0, 0, 0]
# ```
#
# the accuracy will still be **1.0** because the grouping of points is identical, even though the numerical labels are swapped.
#
# ## How the Metric is Computed
#
# 1. **Contingency Matrix**:
#    - Construct a contingency matrix that represents the overlap between the true clusters and the predicted clusters.
#
# 2. **Optimal Correspondence**:
#    - Use an optimization algorithm, such as the Hungarian method (linear sum assignment), to find the best possible correspondence between true and predicted labels, maximizing the number of correctly assigned data points.
#
# 3. **Accuracy Calculation**:
#    - Calculate the accuracy as the ratio of correctly matched data points to the total number of data points.
#
# > This approach ensures that the evaluation is based on **cluster completeness** and **homogeneity**, rewarding cluster assignments that correctly group the same data points together, regardless of the specific labels used.
#
# ---

# %%
from typing import Any
import numpy as np
import sklearn.metrics
import scipy.optimize

def calculate_clustering_accuracy(true_labels: np.ndarray, cluster_labels: np.ndarray) -> float:
    """
    Calculate the clustering accuracy between true labels and cluster labels.

    The function constructs a contingency matrix between the true labels and cluster labels.
    It then uses the Hungarian algorithm (also known as linear sum assignment) to find the
    best matching between the cluster labels and true labels. The clustering accuracy is 
    calculated as the number of correctly matched labels divided by the total number of labels.

    Args:
        true_labels (np.ndarray): An array of true labels for each data point.
        cluster_labels (np.ndarray): An array of cluster labels predicted by a clustering algorithm.

    Returns:
        float: The clustering accuracy, a value between 0 and 1 representing the proportion of 
               correctly matched labels.
    
    Example:
        >>> true_labels = np.array([0, 1, 2, 0, 1, 2])
        >>> cluster_labels = np.array([1, 2, 0, 1, 2, 0])
        >>> calculate_clustering_accuracy(true_labels, cluster_labels)
        1.0

    Raises:
        ValueError: If true_labels and cluster_labels are not of the same length.
    """
    # Check if the input labels are of the same length
    if true_labels.size != cluster_labels.size:
        raise ValueError("true_labels and cluster_labels must have the same length.")

    # Construct a contingency matrix where each cell [i, j] indicates the number of points with 
    # true label i and cluster label j.
    contingency_matrix = sklearn.metrics.cluster.contingency_matrix(true_labels, cluster_labels)
    
    # Find the best matching between true labels and cluster labels using the Hungarian algorithm.
    # We negate the contingency matrix because linear_sum_assignment finds the minimum cost assignment.
    row_ind, col_ind = scipy.optimize.linear_sum_assignment(-contingency_matrix)
    
    # Calculate the number of correctly assigned labels according to the optimal matching.
    correct_pairs = contingency_matrix[row_ind, col_ind].sum()
    
    # Compute the clustering accuracy as the ratio of correctly matched labels to total labels.
    accuracy = correct_pairs / true_labels.size

    return accuracy

# %%
true_labels = np.array([0, 1, 2, 0, 1, 2])
cluster_labels = np.array([1, 2, 0, 1, 2, 0])
calculate_clustering_accuracy(true_labels, cluster_labels)
# Out:
# 1.0

# %%
true_labels = np.array([0, 0, 0, 0, 0, 0])
cluster_labels = np.array([1, 2, 0, 1, 2, 0])
calculate_clustering_accuracy(true_labels, cluster_labels)
# Out:
# 0.3333333333333333

# %%
true_labels = np.array([1, 1, 1, 2, 2, 2])
cluster_labels = np.array([0, 0, 0, 0, 0, 0])
calculate_clustering_accuracy(true_labels, cluster_labels)
# Out:
# 0.5
